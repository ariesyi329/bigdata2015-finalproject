# %%
import csv,sys,os
import numpy
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib.path import Path
from datetime import date,datetime
from rtree import index as rtree
import shapefile  
from pyproj import Proj, transform

filename_all = '../out.csv'
df_in = pd.read_csv(filename_all)

# %%
df_in.head()
# Out:
#    Unnamed: 0                         medallion  \
# 0           0  4B37DE7600AEF9C61F784B05FDEEE0E9
# 1           1  EEC9C6596BD11B4F213367BEF164ED40
# 2           2  B009310787A68502FFD50A2F9CB5CE26
# 3           3  A408F138216DE3E432BBF2FD88665A88
# 4           4  C46A099283B423340CD9CC2837E73761
#
#                        hack_license vendor_id      pickup_datetime  \
# 0  1D7E4CD01ED1C7A6E662A2A9A4B7153F       CMT  2013-08-04 00:03:59
# 1  902B96BCB437D747BA50888778132BE4       CMT  2013-08-04 00:16:29
# 2  A44307E7C864D631E9A26B49C25DD23B       CMT  2013-08-04 00:11:00
# 3  82EA6A085709BE93AA9DA363A85A04FF       CMT  2013-08-04 00:04:26
# 4  4339B58CF42D6B3011479B8D9731CA7F       CMT  2013-08-04 00:09:55
#
#   payment_type  fare_amount  surcharge  mta_tax  tip_amount       ...         \
# 0          CRD          7.5        0.5      0.5        2.10       ...
# 1          CRD          6.5        0.5      0.5        1.87       ...
# 2          CRD         14.5        0.5      0.5        3.00       ...
# 3          CRD         12.5        0.5      0.5        3.37       ...
# 4          CRD          7.5        0.5      0.5        1.50       ...
#
#       dropoff_datetime  passenger_count  trip_time_in_secs trip_distance  \
# 0  2013-08-04 00:12:46                2                527           1.3
# 1  2013-08-04 00:21:41                1                311           1.2
# 2  2013-08-04 00:21:57                1                656           4.3
# 3  2013-08-04 00:18:27                1                840           3.2
# 4  2013-08-04 00:18:53                1                538           1.0
#
#   pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0       -74.008743        40.738098         -73.992302         40.743961
# 1       -73.955505        40.776752         -73.942024         40.786846
# 2       -73.993073        40.698143         -73.979675         40.657543
# 3       -73.954834        40.765484         -73.999046         40.760777
# 4       -73.988869        40.723156         -74.001343         40.731052
#
#    zipcode_pickup  zipcode_dropoff
# 0           10014            10001
# 1           10028            10029
# 2           11201            11215
# 3           10021            10036
# 4           10003            10012
#
# [5 rows x 24 columns]
