# %%
import pandas as pd

# %%
pwd
# Out:
# u'/Users/panding/bigdata/bigdata2015-finalproject/pd878'

# %%
cd
# Out:
# /Users/panding

# %%
ls
# Out:
# Anaconda-2.2.0-MacOSX-x86_64.pkg                 event (1).ics
# Assignment7.docx                                 event (2).ics
# Assignment7.pdf                                  event.ics
# Assignment8.pdf                                  googlechrome.dmg
# DropboxInstaller.dmg                             installgoogledrive.dmg
# Employee.py                                      mrjoin_final.ppt
# Img386211505.jpg                                 my1288_assignment_10/
# PostalBoundary.dbf                               my1288_assignment_10.zip
# R10931049_SL860.csv                              nycTaxiTripData2013.torrent
# R10931144_SL860.csv                              pd878 (1).html
# Sublime Text 2.0.2.dmg                           pd878 (2).html
# VirtualBox-4.3.26-98988-OSX.dmg                  pd878.html
# VisTrails.pdf                                    print-service-ny-mac.pkg
# assignment5 (1).html                             sf3_inc_p_z1.xls
# ...

# %%
cd Downloads/
# Out:
# /Users/panding/Downloads

# %%
df = pd.read_csv('R10931144_SL860.csv')

# %%
df.head(5)
# Out:
#    Geo_FIPS     Geo_GEOID     Geo_NAME    Geo_QName Geo_STUSAB  Geo_SUMLEV  \
# 0    600601  86000US00601  00601 ZCTA5  00601 ZCTA5         pr         860
# 1    600602  86000US00602  00602 ZCTA5  00602 ZCTA5         pr         860
# 2    600603  86000US00603  00603 ZCTA5  00603 ZCTA5         pr         860
# 3    600606  86000US00606  00606 ZCTA5  00606 ZCTA5         pr         860
# 4    600610  86000US00610  00610 ZCTA5  00610 ZCTA5         pr         860
#
#    Geo_GEOCOMP Geo_FILEID  Geo_LOGRECNO  Geo_US     ...       SE_T129_007  \
# 0            0      ACSSF          7371     NaN     ...               517
# 1            0      ACSSF          7372     NaN     ...              1271
# 2            0      ACSSF          7373     NaN     ...               627
# 3            0      ACSSF          7374     NaN     ...               271
# 4            0      ACSSF          7375     NaN     ...              1187
#
#    SE_T129_008  SE_T129_009  SE_T129_010  SE_T147_001  SE_T133_001  \
# ...

# %%
zip_list = [item[0] for item in df['Geo_NAME'].str.split()]

df['Geo_NAME'].update(pd.Series(zip_list))
df.head(5)
# Out:
#    Geo_FIPS     Geo_GEOID Geo_NAME    Geo_QName Geo_STUSAB  Geo_SUMLEV  \
# 0    600601  86000US00601    00601  00601 ZCTA5         pr         860
# 1    600602  86000US00602    00602  00602 ZCTA5         pr         860
# 2    600603  86000US00603    00603  00603 ZCTA5         pr         860
# 3    600606  86000US00606    00606  00606 ZCTA5         pr         860
# 4    600610  86000US00610    00610  00610 ZCTA5         pr         860
#
#    Geo_GEOCOMP Geo_FILEID  Geo_LOGRECNO  Geo_US     ...       SE_T129_007  \
# 0            0      ACSSF          7371     NaN     ...               517
# 1            0      ACSSF          7372     NaN     ...              1271
# 2            0      ACSSF          7373     NaN     ...               627
# 3            0      ACSSF          7374     NaN     ...               271
# 4            0      ACSSF          7375     NaN     ...              1187
#
#    SE_T129_008  SE_T129_009  SE_T129_010  SE_T147_001  SE_T133_001  \
# ...

# %%
df.head(5)
# Out:
#    Geo_FIPS     Geo_GEOID Geo_NAME    Geo_QName Geo_STUSAB  Geo_SUMLEV  \
# 0    600601  86000US00601    00601  00601 ZCTA5         pr         860
# 1    600602  86000US00602    00602  00602 ZCTA5         pr         860
# 2    600603  86000US00603    00603  00603 ZCTA5         pr         860
# 3    600606  86000US00606    00606  00606 ZCTA5         pr         860
# 4    600610  86000US00610    00610  00610 ZCTA5         pr         860
#
#    Geo_GEOCOMP Geo_FILEID  Geo_LOGRECNO  Geo_
df2.head(5)
# Out:
#   Geo_NAME  SE_T001_001  SE_T002_001  SE_T002_002  SE_T002_003  SE_T003_001  \
# 0    00601        18450        18450     286.7235    64.347708     64.65632
# 1    00602        41302        41302    1349.1510    30.613331     32.33005
# 2    00603        53683        53683    1698.0650    31.614216     31.68504
# 3    00606         6591         6591     155.7821    42.309101     42.31392
# 4    00610        28963        28963     806.4141    35.915790     37.52661
#
#    SE_T003_002  SE_T003_003  SE_T004_001  SE_T004_002     ...       \
# 0     64.34771     0.308610        18450         8983     ...
# 1     30.61333     1.716716        41302        20272     ...
# 2     31.61422     0.070821        53683        26240     ...
# 3     42.30910     0.004821         6591         3192     ...
# 4     35.91579     1.610819        28963        14040     ...
#
#    SE_T129_007  SE_T129_008  SE_T129_009  SE_T129_010  SE_T147_001  \
# ...

# %%
df2.describe()
# Out:
#          SE_T001_001    SE_T002_001    SE_T002_002   SE_T002_003  \
# count   33120.000000   33120.000000   33120.000000  33120.000000
# mean     9516.959994    9516.959994    1270.778792     86.628713
# std     13939.177211   13939.177211    4932.474810    253.371709
# min         0.000000       0.000000       0.000000      0.001967
# 25%       721.000000     721.000000      20.211702      9.054230
# 50%      2801.500000    2801.500000      79.085315     35.887930
# 75%     13000.000000   13000.000000     660.399125     88.554361
# max    114734.000000  114734.000000  184475.200000  13430.990142
#
#         SE_T003_001   SE_T003_002   SE_T003_003    SE_T004_001   SE_T004_002  \
# count  33120.000000  33120.000000  33120.000000   33120.000000  33120.000000
# mean      88.601858     86.628713      1.973145    9516.959994   4679.849940
# std      258.815694    253.371701     12.769445   13939.177211   6820.616206
# ...

# %%
cd /Users/panding/bigdata/bigdata2015-finalproject/pd878
# Out:
# /Users/panding/bigdata/bigdata2015-finalproject/pd878

# %%
cd ../
# Out:
# /Users/panding/bigdata/bigdata2015-finalproject

# %%
cd other-data/
# Out:
# /Users/panding/bigdata/bigdata2015-finalproject/other-data

# %%
ls
# Out:
# Untitled0.ipynb   cleaning1.ipynb   sf3_inc_p_z1.xls  zip_borough.csv

# %%
df_zip_bor = pd.read_csv('zip_borough.csv')

# %%
df_zip_bor.head(5)
# Out:
#    Incident Zip    Borough
# 0         10468      BRONX
# 1         10472      BRONX
# 2         10031  MANHATTAN
# 3         10460      BRONX
# 4         10027  MANHATTAN

# %%
zip_list = df_zip_bor['Incident Zip'].tolist()

# %%
zip_str = []
for i in zip_list:
    zip_str.append(str(i))

# %%
df3= df2.loc[df2['Geo_NAME'].isin(zip_str)]
df3.head(5)
# Out:
#      Geo_NAME  SE_T001_001  SE_T002_001  SE_T002_002  SE_T002_003  \
# 2558    10001        21966        21966    35349.600     0.621393
# 2559    10002        82191        82191    93461.170     0.879413
# 2560    10003        57310        57310    99418.490     0.576452
# 2561    10004         2807         2807     5014.745     0.559749
# 2562    10005         6822         6822    92791.040     0.073520
#
#       SE_T003_001  SE_T003_002  SE_T003_003  SE_T004_001  SE_T004_002  \
# 2558     0.621393     0.621393            0        21966        10732
# 2559     0.879413     0.879413            0        82191        39802
# 2560     0.576452     0.576452            0        57310        27442
094_002', u'SE_T094_003', u'SE_T101_001', u'SE_T104_001', u'SE_T106_001', u'SE_T128_001', u'SE_T128_002', u'SE_T128_009', u'SE_T128_010', u'SE_T128_003', u'SE_T128_004', u'SE_T128_005', u'SE_T128_006', u'SE_T128_007', u'SE_T128_008', u'SE_T129_003', u'SE_T129_004', u'SE_T129_005', u'SE_T129_006', u'SE_T129_007', u'SE_T129_008', u'SE_T129_009', u'SE_T129_010', u'SE_T147_001', u'
# ...

# %%
df4.columns = ['Zip Code', 'Total Population', 'Population Density (per sq. mile)', 'Male', 'Female',\
               'White Alone','Black or African American Alone', 'American Indian and Alaska Native Alone',\
               'Asian Alone', 'Native Hawaiian and Other Pacific Islander Alone',\
               'Some Other Race Alone','Two or More races', 'Average Household Size','High school or more',\
               "Bachelor's degree or more", "Master's degree or more", \
               'Civilian Population In Labor Force 16 Years And Over', 'Employed','Unemployed',\
               'Total Employed Civilian Population 16 Years And Over', \
               'Agriculture, forestry, fishing and hunting, and mining', 'Construction',\
               'Manufacturing', 'Wholesale trade', 'Retail trade', 'Transportation and warehousing, and utilities',\
               'Information', 'Finance and insurance, and real estate and rental and leasing',\
               'Professional, scientific, and management, and administrative and waste management services',\
               'Educational services, and health care and social assistance',\
               'Arts, entertainment, and recreation, and accommodation and food services',\
               'Other services, except public administration','Public administration',\
               'Median household income', 'Average Household Income','Per Capita Income',\
               'Gini Index Of Income Inequality','Occupied Housing Units', 'Owner Occupied',\
               'Renter Occupied','Median House Value For All Owner-Occupied Housing Units', \
               'Median Gross Rent', 'Average Gross Rent','Workers 16 Years and over', 'Car, truck, or van',\
               'Drove Alone', 'Carpooled', 'Public transportation (Includes Taxicab)', \
               'Motorcycle', 'Bicycle', 'Walked', 'Other means', 'Worked at home', \
               'Less than 10 minutes', '10 to 19 minutes','20 to 29 minutes','30 to 39 minutes',\
               '40 to 59 minutes','60 to 89 minutes','90 or More minutes','Worked at home',\
               'Average Commute to Work (in min)', 'Total Population','Native Born',\
               'Foreign Born', 'Naturalized Citizen', 'Not a Citizen']
df4
# Out:
#      Zip Code  Total Population  Population Density (per sq. mile)   Male  \
# 2558    10001             21966                        35349.60000  10732
# 2559    10002             82191                        93461.17000  39802
# 2560    10003             57310                        99418.49000  27442
# 2561    10004              2807                         5014.74500   1469
# 2562    10005              6822                        92791.04000   3463
# 2563    10006              2507                        27306.71000   1137
# 2564    10007              6525                        39918.16000   3661
# 2565    10009             62810                       101865.20000  28842
# 2566    10010             30670                        78507.05000  14327
# 2567    10011             52167                        79233.23000  26039
# 2568    10012             26145                        80873.23000  13691
# 2569    10013             26065                        47193.77000  12862
# ...

# %%
#df4.to_csv(file_name, sep='\t')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-131-0c4899f4b4ee> in <module>()
# ----> 1 pwd
#       2 #df4.to_csv(file_name, sep='\t')
#
# NameError: name 'pwd' is not defined

# %%
ls
# Out:
# Untitled0.ipynb   cleaning1.ipynb   sf3_inc_p_z1.xls  zip_borough.csv

# %%
cd /Users/panding/bigdata/bigdata2015-finalproject/pd878
# Out:
# /Users/panding/bigdata/bigdata2015-finalproject/pd878

# %%
df4.to_csv('NYC_census.csv')
